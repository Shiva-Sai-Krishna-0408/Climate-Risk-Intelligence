# %%
import folium
import pandas as pd

# %%
def get_color(risk_score):
    return "green" if risk_score <= 25 else "orange" if risk_score > 25 and risk_score <= 50 else "red" if risk_score > 50 and risk_score <= 75 else "darkred"

df = pd.read_csv(r"C:\Users\Shiva\Projects\climate-risk-intelligence\data\india_features_v2.csv")
india_map = folium.Map(location=[20.5937,78.9629],zoom_start=5)

# %%
for _,row in df.iterrows():
    folium.CircleMarker(
        location = [row["latitude"],row["longitude"]],
        radius = 10,
        color = get_color(row["risk_score"]),
        fill = True,
        fill_color = get_color(row["risk_score"]),
        fill_opacity=0.6,
        popup=f"{row['name']} | Risk Score: {row['risk_score']}",
        tool_tip="Click me"
    ).add_to(india_map)

# %%
india_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c81e6f0efed787a2a6e72fc31ed0780b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c81e6f0efed787a2a6e72fc31ed0780b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c81e6f0efed787a2a6e72fc31ed0780b = L.map(
#                 &quot;map_c81e6f0efed787a2a6e72fc31ed0780b&quot;,
#                 {
#                     center: [20.5937, 78.9629],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3fc6f6acc68fc7a33894ebe5bc951bc1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3fc6f6acc68fc7a33894ebe5bc951bc1.addTo(map_c81e6f0efed787a2a6e72fc31ed0780b);
#
#
#             var circle_marker_cb1fede917d90bd571b3dc3c7ebba429 = L.circleMarker(
#                 [28.563262, 77.186937],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c81e6f0efed787a2a6e72fc31ed0780b);
#
#
#         var popup_e98c48f68da9e16a42be1a71b829499a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ed9704619192218a2318dd7fd77ad5f4 = $(`&lt;div id=&quot;html_ed9704619192218a2318dd7fd77ad5f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;R K Puram, Delhi - DPCC | Risk Score: 63.0&lt;/div&gt;`)[0];
#                 popup_e98c48f68da9e16a42be1a71b829499a.setContent(html_ed9704619192218a2318dd7fd77ad5f4);
#
#
#
#         circle_marker_cb1fede917d90bd571b3dc3c7ebba429.bindPopup(popup_e98c48f68da9e16a42be1a71b829499a)
#         ;
#
#
#
#
#             var circle_marker_e68ddc9742b15c5a09451d5f91dbc4c2 = L.circleMarker(
#                 [28.674045, 77.131023],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c81e6f0efed787a2a6e72fc31ed0780b);
#
#
#         var popup_c1c098392ab8efe1da534b2b393d09e0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_79d36d75d47d001c5f13b04eef5dc254 = $(`&lt;div id=&quot;html_79d36d75d47d001c5f13b04eef5dc254&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Punjabi Bagh, Delhi - DPCC | Risk Score: 66.5&lt;/div&gt;`)[0];
#                 popup_c1c098392ab8efe1da534b2b393d09e0.setContent(html_79d36d75d47d001c5f13b04eef5dc254);
#
#
#
#         circle_marker_e68ddc9742b15c5a09451d5f91dbc4c2.bindPopup(popup_c1c098392ab8efe1da534b2b393d09e0)
#         ;
#
#
#
#
#             var circle_marker_a0c17a1703a126efdf99e3247c403109 = L.circleMarker(
#                 [28.6235, 77.2494],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkred&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkred&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c81e6f0efed787a2a6e72fc31ed0780b);
#
#
#         var popup_5f380cc42096d0ed0be25fda8f6cc8f2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2ae733fc8c040ce4fc976e20873264e5 = $(`&lt;div id=&quot;html_2ae733fc8c040ce4fc976e20873264e5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Income Tax Office, Delhi - CPCB | Risk Score: 75.5&lt;/div&gt;`)[0];
#                 popup_5f380cc42096d0ed0be25fda8f6cc8f2.setContent(html_2ae733fc8c040ce4fc976e20873264e5);
#
#
#
#         circle_marker_a0c17a1703a126efdf99e3247c403109.bindPopup(popup_5f380cc42096d0ed0be25fda8f6cc8f2)
#         ;
